# %% [markdown]
# <a href="https://colab.research.google.com/github/ivan-rib/Amablindados/blob/main/WORKSHOPAMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
import os

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#path='/content/drive/My Drive/WorkshopAMA'
#dir_list = os.listdir(path) 
  
#print("Files and directories in '", path, "' :") 
#print(dir_list)
#files=['2S2021.csv', '2S2020.txt', '2S2019.csv', '2S2018.csv', '2S2017.csv', '1S2021.csv', '01S2020.csv', '1S2019.csv', '1S2018.csv', '1S2017.csv']

# %%
file_list=['2S2021.csv', '2S2020.txt', '2S2019.csv', '2S2018.csv', '2S2017.csv', '1S2021.csv', '01S2020.csv', '1S2019.csv', '1S2018.csv', '1S2017.csv']
  
main_dataframe = pd.DataFrame(pd.read_csv('/content/drive/My Drive/WorkshopAMA/'+file_list[0],encoding='utf-16', on_bad_lines='skip',sep="\t"))
  
for i in range(1,len(file_list)):
    data = pd.read_csv('/content/drive/My Drive/WorkshopAMA/'+file_list[i],encoding='utf-16', on_bad_lines='skip',sep="\t")
    df = pd.DataFrame(data)
    main_dataframe = pd.concat([main_dataframe,df])
main_dataframe
# Out:
#                CNPJ emit.                               Emitente     No.  \
# 0      61.412.110/0192-55                 DROGARIA SAO PAULO S.A  128488
# 1      24.120.893/0001-77  CB ANHEMBI COMERCIO DE ALIMENTOS LTDA  555624
# 2      47.508.411/0006-60         CIA BRASILEIRA DE DISTRIBUICAO  117783
# 3      47.508.411/0288-32         CIA BRASILEIRA DE DISTRIBUICAO  113715
# 4      45.543.915/0358-05             CARREFOUR COM. E IND. LTDA  222025
# ...                   ...                                    ...     ...
# 26930  61.585.865/1373-78                      RAIA DROGASIL S A   21290
# 26931  05.513.952/0001-22                AUTO POSTO TECOARA LTDA  143111
# 26932  05.513.952/0001-22                AUTO POSTO TECOARA LTDA  143105
# 26933  05.513.952/0001-22                AUTO POSTO TECOARA LTDA  143045
# 26934  05.513.952/0001-22                AUTO POSTO TECOARA LTDA  142873
#
#       Data Emissão Valor NF Data Registro Créditos Situação do Crédito
# ...
